# %%
import numpy as np

# %%
arr = np.random.randn(5,4)
arr
# Out:
# <pre>array([[ 0.08913938, -0.16469465,  1.46667678, -0.39130447],
#        [-0.66611074,  0.09265858,  0.4767354 ,  0.27715368],
#        [ 0.27538413,  0.67518878, -0.29460084,  0.59534853],
#        [-2.04264971, -2.19134684,  0.26422676,  0.60761024],
#        [ 0.12892409, -1.45942674, -1.40324637,  0.81663416]])</pre>

# %%
arr.mean()
# Out:
# -0.14238499313352665

# %%
arr.mean(axis=0)
# Out:
# <pre>array([-0.44306257, -0.60952418,  0.10195835,  0.38108843])</pre>

# %%
arr = np.array([1,2,4,5,6,7,9,11,22])
arr.cumsum()
# Out:
# <pre>array([ 1,  3,  7, 12, 18, 25, 34, 45, 67])</pre>

# %%
arr.cumprod()
# Out:
# <pre>array([      1,       2,       8,      40,     240,    1680,   15120,
#         166320, 3659040])</pre>

# %%
arr = np.array([[0,1,2],[6,7,8],[10,15,19]])
arr
# Out:
# <pre>array([[ 0,  1,  2],
#        [ 6,  7,  8],
#        [10, 15, 19]])</pre>

# %%
arr.cumsum(axis=1)
# Out:
# <pre>array([[ 0,  1,  3],
#        [ 6, 13, 21],
#        [10, 25, 44]])</pre>

# %%
arr.cumprod(axis=0)
# Out:
# <pre>array([[  0,   1,   2],
#        [  0,   7,  16],
#        [  0, 105, 304]])</pre>

# %%
arr = np.random.randn(100)
(arr>0).sum()
# Out:
# 54

# %%
bools = np.array([False,True,True,False])
bools.any()
# Out:
# True

# %%
bools.all()
# Out:
# False

# %%
names = np.array(['Jan','Anna','Henryk','Jan','Anna','Anna','Olaf'])
np.unique(names)
# Out:
# <pre>array(['Anna', 'Henryk', 'Jan', 'Olaf'], dtype='%lt;U6')</pre>

# %%
lb = np.array([3,5,6,7,1,2,3,4,2,3,4,5,2,3,4])
u = np.unique(lb)
print(u)
# Out:
# [1 2 3 4 5 6 7]

# %%
#sorted(u)
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %%
print(u)
# Out:
# [1 2 3 4 5 6 7]

# %%
u.sort()
u
# Out:
# <pre>array([1, 2, 3, 4, 5, 6, 7])</pre>

# %%
sorted(names)
# Out:
# ['Anna', 'Anna', 'Anna', 'Henryk', 'Jan', 'Jan', 'Olaf']

# %%
names
# Out:
# <pre>array(['Jan', 'Anna', 'Henryk', 'Jan', 'Anna', 'Anna', 'Olaf'],
#       dtype='%lt;U6')</pre>

# %%
values = np.array([6,0,0,3,2,5,6])
np.in1d(values,[2,3,6])
# Out:
# <pre>array([ True, False, False,  True,  True, False,  True])</pre>
